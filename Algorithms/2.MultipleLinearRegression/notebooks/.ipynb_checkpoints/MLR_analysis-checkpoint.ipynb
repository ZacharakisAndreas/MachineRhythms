# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data_raw = pd.read_csv('../../../../datasets/Greece - Agriculture and Rural Development/agriculture-and-rural-development_grc.csv')
pd.set_option('display.max_columns', 10)
data_raw.head()
# Out:
#    Agricultural land (% of land area)  Agricultural land (sq. km)  \
# 0                                 NaN                         NaN
# 1                           69.123351                     89100.0
# 2                           69.061288                     89020.0
# 3                           69.984484                     90210.0
# 4                           69.751746                     89910.0
#
#    Agricultural machinery, tractors  \
# 0                               NaN
# 1                           22630.0
# 2                           24530.0
# 3                           28500.0
# 4                           33500.0
#
#    Agricultural machinery, tractors per 100 sq. km of arable land  \
# 0                                                NaN
# 1                                          80.994989
# 2                                          85.679357
# 3                                          93.228656
# 4                                         111.629457
#
# ...

# %%
variable_x1 = "Crop production index (2014-2016 = 100)"
variable_x2 = "Fertilizer consumption (% of fertilizer production)"
variable_x21 = "Fertilizer consumption (kilograms per hectare of arable land)"
variable_x22 = "Land under cereal production (hectares)"
variable_y = "Cereal production (metric tons)"
data = data_raw[[variable_x, variable_y]].dropna().reset_index(drop=True)
data.head()
# Out:
#    Crop production index (2014-2016 = 100)  Cereal production (metric tons)
# 0                                62.570000                        2243876.0
# 1                                50.700001                        2426843.0
# 2                                57.430000                        2122537.0
# 3                                57.150002                        2874641.0
# 4                                61.770000                        2940922.0
